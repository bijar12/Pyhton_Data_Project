# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import  load_dataset

#loading data set
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset["train"].to_pandas()

# Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df.tail(10)
# Out:
#              job_title_short  \
# 785731         Data Engineer
# 785732         Data Engineer
# 785733     Software Engineer
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785733                                    DevOps Engineer
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                   job_location                     job_via  \
# 785731  Overland Park, Kansas, Amerika Serikat            melalui LinkedIn
# 785732                      Heidelberg, Jerman  melalui Top County Careers
# 785733                               Singapura         melalui Trabajo.org
# 785734                      Almaty, Kazakhstan               melalui Melga
# 785735                          Berlin, Jerman  melalui Top County Careers
# 785736                               Singapura         melalui Trabajo.org
# 785737                      Bad Rodach, Jerman   melalui BeBee Deutschland
# 785738                                Malaysia            melalui Ricebowl
# 785739     Newark, New Jersey, Amerika Serikat         melalui Recruit.net
# 785740                                   India              melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785731   Pekerjaan tetap               False           Sudan
# 785732   Pekerjaan tetap               False         Germany
# 785733   Pekerjaan tetap               False       Singapore
# 785734   Pekerjaan tetap               False      Kazakhstan
# 785735   Pekerjaan tetap               False         Germany
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785731 2023-03-12 06:32:17                  False                 False
# 785732 2023-03-13 06:18:59                  False                 False
# 785733 2023-03-13 06:16:17                  False                 False
# 785734 2023-03-12 06:31:13                  False                 False
# 785735 2023-03-13 06:19:07                  False                 False
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785731       Sudan        None              NaN              NaN
# 785732     Germany        None              NaN              NaN
# 785733   Singapore        None              NaN              NaN
# 785734  Kazakhstan        None              NaN              NaN
# 785735     Germany        None              NaN              NaN
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785731        Shamrock Trading Corporation
# 785732                Heidelberg Materials
# 785733                   Hydra X Pte. Ltd.
# 785734           Staff-UP Consulting Group
# 785735                            Pure App
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785731  ['nosql', 'mongodb', 'mongodb', 'python', 'ela...
# 785732  ['python', 'c#', 'java', 'scala', 'sql', 'post...
# 785733                           ['docker', 'kubernetes']
# 785734                                        ['windows']
# 785735  ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785731  {'analyst_tools': ['excel'], 'cloud': ['aws', ...
# 785732  {'cloud': ['azure', 'databricks'], 'databases'...
# 785733                {'other': ['docker', 'kubernetes']}
# 785734                                {'os': ['windows']}
# 785735  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df['job_title_short'].head(10)
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# 5           Data Engineer
# 6    Senior Data Engineer
# 7           Data Engineer
# 8        Business Analyst
# 9          Data Scientist
# Name: job_title_short, dtype: object

# %%
df[['job_title_short']]
# Out:
#              job_title_short
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
# [785741 rows x 1 columns]

# %%
df[['job_title_short','job_location']].head(100)
# Out:
#          job_title_short                  job_location
# 0   Senior Data Engineer                 Watertown, CT
# 1           Data Analyst  Guadalajara, Jalisco, Mexico
# 2          Data Engineer               Berlin, Germany
# 3          Data Engineer               San Antonio, TX
# 4          Data Engineer                Washington, DC
# ..                   ...                           ...
# 95         Data Engineer    Mumbai, Maharashtra, India
# 96         Data Engineer                  Torrance, CA
# 97          Data Analyst                United Kingdom
# 98  Senior Data Engineer           Toronto, ON, Canada
# 99         Data Engineer                     Miami, FL
#
# [100 rows x 2 columns]

# %%
#df.iloc[90:100 , 0:2]

# %%
#df.iloc[90:100]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
len(df)
# Out:
# 785741

# %%
df.shape
# Out:
# (785741, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df.job_title_short == "Data Analyst"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
df[df.job_title_short== "Data Analyst"]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# 12                      Lyon, France
# 18                    Warsaw, Poland
# 31                     Paris, France
# 34                 Erlangen, Germany
# ...                              ...
# 785703                      Anywhere
# 785705                   Oakland, CA
# 785715                         India
# 785717                Erfurt, Jerman
# 785737            Bad Rodach, Jerman
#
#                                                   job_via  \
# 1                                        via BeBee México
# 12                                           via Jobijoba
# 18                                  via Praca Trabajo.org
# 31                                           via LinkedIn
# 34                        via Central Illinois Proud Jobs
# ...                                                   ...
# 785703                                       via Snagajob
# 785705                                       via Snagajob
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...
# 785717                                   melalui LinkedIn
# 785737                          melalui BeBee Deutschland
#
#                job_schedule_type  job_work_from_home  \
# 1                      Full-time               False
# 12      Full-time and Internship               False
# 18                     Full-time               False
# 31      Full-time and Internship               False
# 34                     Full-time               False
# ...                          ...                 ...
# 785703                 Full-time                True
# 785705                 Full-time               False
# 785715           Pekerjaan tetap               False
# 785717           Pekerjaan tetap               False
# 785737           Pekerjaan tetap               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 1                          Mexico 2023-01-14 13:18:07                  False
# 12                         France 2023-12-22 13:24:41                  False
# 18                         Poland 2023-10-16 13:36:54                  False
# 31                         France 2023-10-19 13:59:31                  False
# 34                        Germany 2023-02-23 13:31:28                   True
# ...                           ...                 ...                    ...
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
# 785715                      India 2023-03-13 06:16:28                  False
# 785717                    Germany 2023-03-12 06:18:18                  False
# 785737                    Germany 2023-03-12 06:18:18                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 1                      False         Mexico        None              NaN
# 12                     False         France        None              NaN
# 18                     False         Poland        None              NaN
# 31                     False         France        None              NaN
# 34                     False        Germany        None              NaN
# ...                      ...            ...         ...              ...
# 785703                 False  United States        None              NaN
# 785705                 False  United States        None              NaN
# 785715                 False          India        None              NaN
# 785717                 False        Germany        None              NaN
# 785737                 False        Germany        None              NaN
#
#         salary_hour_avg                                       company_name  \
# 1                   NaN                         Hewlett Packard Enterprise
# 12                  NaN                                              Engie
# 18                  NaN                                              Glovo
# 31                  NaN  GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 34                  NaN                                       DEFACTO GmbH
# ...                 ...                                                ...
# 785703              NaN                        Axelon Services Corporation
# 785705              NaN                                   PG&E Corporation
# 785715              NaN                                               Amul
# 785717              NaN                                      NTT DATA DACH
# 785737              NaN                                   HABA FAMILYGROUP
#
#                                                job_skills  \
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 12      ['sql', 'php', 'excel', 'power bi', 'sap', 'ji...
# 18      ['sql', 'python', 'r', 'redshift', 'pandas', '...
# 31                                                ['sql']
# 34                                                ['sap']
# ...                                                   ...
# 785703                                               None
# 785705                       ['sql', 'python', 'tableau']
# 785715                                               None
# 785717                                   ['aws', 'azure']
# 785737                     ['sas', 'sas', 'sql', 'excel']
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 12      {'analyst_tools': ['excel', 'power bi', 'sap']...
# 18      {'analyst_tools': ['excel', 'looker', 'tableau...
# 31                               {'programming': ['sql']}
# 34                             {'analyst_tools': ['sap']}
# ...                                                   ...
# 785703                                               None
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
# 785715                                               None
# 785717                        {'cloud': ['aws', 'azure']}
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
#
# [196075 rows x 17 columns]

# %%
#df[(df.job_title_short== "Data Analyst") & (df.salary_year_avg.notna())]

# %%
#df[(df.job_title_short== "Data Analyst") | (df.salary_year_avg > 100000)]

# %%
df.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %% [markdown]
# # Data/Pandas Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
type(df.job_posted_date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['job_posted_date']=pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df['job_posted_month']=df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
#  17  job_posted_month       785741 non-null  int32
# dtypes: bool(3), datetime64[ns](1), float64(2), int32(1), object(11)
# memory usage: 89.2+ MB

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills  job_posted_month
# 0                                                    None                 6
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...                 1
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...                10
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...                 7
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...                 8
# ...                                                   ...               ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...                 3
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...                 3
# 785738         {'analyst_tools': ['powerpoint', 'excel']}                 3
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...                 3
# 785740              {'cloud': ['aws'], 'other': ['flow']}                 3
#
# [785741 rows x 18 columns]

# %%
df.sort_values(by='job_posted_date', inplace=True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# 327439                                Staff engineer data
# 112373  Marketing Data & Analytics Product Owner - Sen...
# 90102                                Intelligence analyst
#
#                   job_location                      job_via job_schedule_type  \
# 108804            New York, NY            via CareerBuilder         Full-time
# 96906           Bloomfield, CT            via CareerBuilder         Full-time
# 98438           Washington, DC            via CareerBuilder         Full-time
# 110290             Fairfax, VA            via CareerBuilder         Full-time
# 72158            Worcester, MA                 via LinkedIn         Full-time
# ...                        ...                          ...               ...
# 362129           Sunnyvale, CA               via Talent.com         Full-time
# 351830       San Francisco, CA               via Talent.com         Full-time
# 327439          Southfield, MI               via Talent.com         Full-time
# 112373  Boston, MA  (+1 other)  via Boston Consulting Group         Full-time
# 90102               Boston, MA               via Talent.com         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# 96906                False  New York, United States 2023-01-01 00:00:07
# 98438                False  New York, United States 2023-01-01 00:00:22
# 110290               False  New York, United States 2023-01-01 00:00:24
# 72158                False  New York, United States 2023-01-01 00:00:27
# ...                    ...                      ...                 ...
# 362129               False                    Sudan 2023-12-31 23:40:31
# 351830               False                    Sudan 2023-12-31 23:40:31
# 327439               False                    Sudan 2023-12-31 23:40:32
# 112373               False  New York, United States 2023-12-31 23:59:58
# 90102                False  New York, United States 2023-12-31 23:59:58
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 108804                  False                 False  United States
# 96906                    True                 False  United States
# 98438                   False                  True  United States
# 110290                  False                 False  United States
# 72158                   False                  True  United States
# ...                       ...                   ...            ...
# 362129                   True                 False          Sudan
# 351830                  False                 False          Sudan
# 327439                  False                 False          Sudan
# 112373                  False                 False  United States
# 90102                    True                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg             company_name  \
# 108804        None              NaN              NaN     Metasys Technologies
# 96906         None              NaN              NaN             Diverse Lynx
# 98438         None              NaN              NaN               Guidehouse
# 110290        None              NaN              NaN                  Protask
# 72158         None              NaN              NaN   Atria Wealth Solutions
# ...            ...              ...              ...                      ...
# 362129        None              NaN              NaN           ITCO Solutions
# 351830        None              NaN              NaN            JBL Resources
# 327439        year         140000.0              NaN        Credit Acceptance
# 112373        None              NaN              NaN  Boston Consulting Group
# 90102         None              NaN              NaN         VirtualVocations
#
#                                                job_skills  \
# 108804  ['sql', 'snowflake', 'visio', 'jira', 'conflue...
# 96906                               ['sql', 'sas', 'sas']
# 98438   ['sql', 'python', 'r', 'azure', 'snowflake', '...
# 110290                                    ['sql', 'jira']
# 72158                        ['sql', 'atlassian', 'jira']
# ...                                                   ...
# 362129  ['sql', 'python', 'java', 'snowflake', 'airflo...
# 351830                      ['azure', 'power bi', 'word']
# 327439                          ['express', 'kubernetes']
# 112373  ['sql', 'python', 'r', 'gdpr', 'tableau', 'pow...
# 90102                                                None
#
#                                           job_type_skills  job_posted_month
# 108804  {'analyst_tools': ['visio'], 'async': ['jira',...                 1
# 96906   {'analyst_tools': ['sas'], 'programming': ['sq...                 1
# 98438   {'analyst_tools': ['tableau', 'excel'], 'cloud...                 1
# 110290        {'async': ['jira'], 'programming': ['sql']}                 1
# 72158   {'async': ['jira'], 'other': ['atlassian'], 'p...                 1
# ...                                                   ...               ...
# 362129  {'cloud': ['snowflake'], 'libraries': ['airflo...                12
# 351830  {'analyst_tools': ['power bi', 'word'], 'cloud...                12
# 327439  {'other': ['kubernetes'], 'webframeworks': ['e...                12
# 112373  {'analyst_tools': ['tableau', 'power bi'], 'li...                12
# 90102                                                None                12
#
# [785741 rows x 18 columns]

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
#  14  job_skills             668704 non-null  object
#  15  job_type_skills        668704 non-null  object
#  16  job_posted_month       785741 non-null  int32
# dtypes: bool(3), datetime64[ns](1), float64(1), int32(1), object(11)
# memory usage: 89.2+ MB

# %%
df.dropna(subset=['salary_year_avg'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
#  14  job_skills             20170 non-null  object
#  15  job_type_skills        20170 non-null  object
#  16  job_posted_month       22003 non-null  int32
# dtypes: bool(3), datetime64[ns](1), float64(1), int32(1), object(11)
# memory usage: 2.5+ MB

# %% [markdown]
# # Basic Pandas Analyzing Data

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  job_posted_month
# count                          22003     22003.000000      22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072          5.886288
# min              2023-01-01 00:02:56     15000.000000          1.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000          3.000000
# 50%              2023-06-11 09:03:27    115000.000000          6.000000
# 75%              2023-08-26 00:41:15    150000.000000          8.000000
# max              2023-12-31 23:40:32    960000.000000         12.000000
# std                              NaN     48312.449482          3.296650

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
#  14  job_skills             20170 non-null  object
#  15  job_type_skills        20170 non-null  object
#  16  job_posted_month       22003 non-null  int32
# dtypes: bool(3), datetime64[ns](1), float64(1), int32(1), object(11)
# memory usage: 2.5+ MB

# %%
df.count()
# Out:
# job_title_short          22003
# job_title                22003
# job_location             21723
# job_via                  22003
# job_schedule_type        21987
# job_work_from_home       22003
# search_location          22003
# job_posted_date          22003
# job_no_degree_mention    22003
# job_health_insurance     22003
# job_country              22003
# salary_rate              22003
# salary_year_avg          22003
# company_name             22003
# job_skills               20170
# job_type_skills          20170
# job_posted_month         22003
# dtype: int64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
df['salary_rate'].idxmin()
# Out:
# 108883

# %%
min_salary = df['salary_rate'].idxmin()

# %%
df['job_title_short'].unique()
# Out:
# array(['Data Scientist', 'Data Engineer', 'Business Analyst',
#        'Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist',
#        'Senior Data Analyst', 'Software Engineer',
#        'Machine Learning Engineer', 'Cloud Engineer'], dtype=object)

# %%
df["job_title_short"].value_counts()
# Out:
# job_title_short
# Data Scientist               5922
# Data Analyst                 5451
# Data Engineer                4500
# Senior Data Scientist        1690
# Senior Data Engineer         1591
# Senior Data Analyst          1131
# Business Analyst              610
# Machine Learning Engineer     576
# Software Engineer             467
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
df.groupby("job_title_short")["salary_year_avg"].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby("job_title_short")["salary_year_avg"].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(["job_title_short", "job_country"])["salary_year_avg"].median()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.0
#                    Australia                70000.0
#                    Bangladesh               16500.0
#                    Belgium                  89100.0
#                    Bulgaria                 71925.0
#                                              ...
# Software Engineer  Ukraine                  54000.0
#                    United Arab Emirates     79200.0
#                    United Kingdom           89100.0
#                    United States           130000.0
#                    Vietnam                  53600.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(['min','max','mean','median'])
# Out:
#                                min       max           mean    median
# job_title_short
# Business Analyst           16500.0  387460.0   91082.612833   85000.0
# Cloud Engineer             42000.0  280000.0  111268.453846   90000.0
# Data Analyst               25000.0  650000.0   93841.907854   90000.0
# Data Engineer              15000.0  525000.0  130125.604250  125000.0
# Data Scientist             27000.0  960000.0  135988.837171  127500.0
# Machine Learning Engineer  30000.0  325000.0  126774.315972  106415.0
# Senior Data Analyst        30000.0  425000.0  113911.363665  111175.0
# Senior Data Engineer       35000.0  425000.0  145840.611624  147500.0
# Senior Data Scientist      45000.0  890000.0  154206.292996  155500.0
# Software Engineer          28000.0  375000.0  113393.760054   99150.0

# %% [markdown]
# # Exercise pandas basics

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     15766
# Sudan              1623
# India               582
# Canada              463
# United Kingdom      287
# Germany             257
# France              237
# Poland              200
# Spain               144
# Portugal            131
# Mexico              111
# Israel              103
# Singapore            98
# South Africa         92
# Netherlands          87
# Greece               82
# Australia            74
# Colombia             69
# Philippines          68
# South Korea          63
# Name: count, dtype: int64

# %%
df["job_country"].isin([""]).any()
# Out:
# False

# %% [markdown]
# # Data Filtering

# %%
pak_jobs = df[df["job_country"]== "Pakistan"]

# %%
pak_jobs
# Out:
#                   job_title_short  \
# 725905          Software Engineer
# 319286          Software Engineer
# 202409              Data Engineer
# 176946  Machine Learning Engineer
# 652867              Data Engineer
# 716278               Data Analyst
# 75724              Data Scientist
# 725631              Data Engineer
# 754068  Machine Learning Engineer
# 647099           Business Analyst
# 35758            Business Analyst
# 87668              Data Scientist
# 784584             Data Scientist
# 694061              Data Engineer
# 742964  Machine Learning Engineer
# 365714       Senior Data Engineer
# 212617  Machine Learning Engineer
# 669770              Data Engineer
# 546486      Senior Data Scientist
# 208197               Data Analyst
# 213687              Data Engineer
# 323311              Data Engineer
# 771324  Machine Learning Engineer
#
#                                                 job_title  \
# 725905             Principal Software Engineer - Big Data
# 319286                           Power BI Developer S4283
# 202409                                Data Engineer S4289
# 176946                                       NLP Engineer
# 652867                    Big Data Engineer (Scala-Spark)
# 716278                                Data Analyst Sc4561
# 75724                                   Sr.Data Scientist
# 725631         Data Engineer (ADF, Databricks, Snowflake)
# 754068                     Lead Machine Learning Engineer
# 647099                      Business Intelligence Analyst
# 35758                 Business Intelligence (BI) Engineer
# 87668                                 Big Data Specialist
# 784584                                     Data Scientist
# 694061                    Tech Lead /Architect - Big Data
# 742964                                Lead AI/ML Engineer
# 365714       Senior Big Data Engineer (AWS+Python+Hadoop)
# 212617                             Senior ML Ops Engineer
# 669770                                      Data Engineer
# 546486  Senior Analytics Engineer I (Pro-active Pipeline)
# 208197                             Financial Data Analyst
# 213687  Data Engineer Jobs In Flipdish for Engineering...
# 323311                                      Data Engineer
# 771324                                 Senior ML Engineer
#
#                job_location                               job_via  \
# 725905             Pakistan                       via Ai-Jobs.net
# 319286  Islamabad, Pakistan                       via Ai-Jobs.net
# 202409     Lahore, Pakistan                       via Ai-Jobs.net
# 176946    Karachi, Pakistan                       via Ai-Jobs.net
# 652867  Islamabad, Pakistan                       via Ai-Jobs.net
# 716278    Karachi, Pakistan                       via Ai-Jobs.net
# 75724      Lahore, Pakistan                       via Ai-Jobs.net
# 725631  Islamabad, Pakistan                       via Ai-Jobs.net
# 754068             Pakistan                       via Ai-Jobs.net
# 647099     Lahore, Pakistan                       via Ai-Jobs.net
# 35758   Islamabad, Pakistan                       via Ai-Jobs.net
# 87668   Islamabad, Pakistan                       via Ai-Jobs.net
# 784584  Islamabad, Pakistan                       via Ai-Jobs.net
# 694061  Islamabad, Pakistan                       via Ai-Jobs.net
# 742964  Islamabad, Pakistan                       via Ai-Jobs.net
# 365714  Islamabad, Pakistan                       via Ai-Jobs.net
# 212617  Islamabad, Pakistan                       via Ai-Jobs.net
# 669770             Pakistan                       via Ai-Jobs.net
# 546486  Islamabad, Pakistan                       via Ai-Jobs.net
# 208197             Pakistan                       via Ai-Jobs.net
# 213687    Karachi, Pakistan  via Get Daily Fresh Jobs Opportunity
# 323311             Pakistan                       via Ai-Jobs.net
# 771324             Pakistan                       via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home search_location  \
# 725905         Full-time               False        Pakistan
# 319286         Full-time               False        Pakistan
# 202409         Full-time               False        Pakistan
# 176946         Full-time               False        Pakistan
# 652867         Full-time               False        Pakistan
# 716278         Full-time               False        Pakistan
# 75724          Full-time               False        Pakistan
# 725631         Full-time               False        Pakistan
# 754068         Full-time               False        Pakistan
# 647099         Full-time               False        Pakistan
# 35758         Contractor               False        Pakistan
# 87668         Contractor               False        Pakistan
# 784584        Contractor               False        Pakistan
# 694061         Full-time               False        Pakistan
# 742964         Full-time               False        Pakistan
# 365714         Full-time               False        Pakistan
# 212617         Full-time               False        Pakistan
# 669770         Full-time               False        Pakistan
# 546486         Full-time               False        Pakistan
# 208197         Full-time               False        Pakistan
# 213687         Full-time               False        Pakistan
# 323311         Full-time               False        Pakistan
# 771324         Full-time               False        Pakistan
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 725905 2023-01-09 21:23:07                  False                 False
# 319286 2023-01-16 17:56:02                  False                 False
# 202409 2023-01-16 22:56:02                  False                 False
# 176946 2023-02-20 15:11:26                  False                 False
# 652867 2023-03-10 10:16:50                   True                 False
# 716278 2023-03-15 02:30:17                  False                 False
# 75724  2023-04-28 00:18:18                  False                 False
# 725631 2023-05-05 21:43:44                  False                 False
# 754068 2023-05-12 20:52:41                  False                 False
# 647099 2023-06-05 12:35:46                  False                 False
# 35758  2023-06-05 13:35:50                  False                 False
# 87668  2023-06-06 00:35:46                  False                 False
# 784584 2023-06-07 06:17:01                  False                 False
# 694061 2023-07-06 10:19:03                   True                 False
# 742964 2023-07-06 20:19:03                  False                 False
# 365714 2023-07-06 23:19:03                   True                 False
# 212617 2023-07-12 22:19:10                  False                 False
# 669770 2023-08-07 11:20:15                   True                 False
# 546486 2023-08-29 20:00:23                  False                 False
# 208197 2023-09-04 22:28:28                  False                 False
# 213687 2023-09-23 22:28:39                  False                 False
# 323311 2023-11-21 18:00:17                  False                 False
# 771324 2023-12-22 01:39:15                  False                 False
#
#        job_country salary_rate  salary_year_avg                 company_name  \
# 725905    Pakistan        year          79200.0           NorthBay Solutions
# 319286    Pakistan        year          79200.0                        Nisum
# 202409    Pakistan        year         133000.0                        Nisum
# 176946    Pakistan        year          50400.0                         Beam
# 652867    Pakistan        year          45000.0             Applaudo Studios
# 716278    Pakistan        year         111175.0                        Nisum
# 75724     Pakistan        year         157500.0                    NielsenIQ
# 725631    Pakistan        year         147500.0                        Nisum
# 754068    Pakistan        year          79200.0           NorthBay Solutions
# 647099    Pakistan        year          50400.0                     Atheneum
# 35758     Pakistan        year          64800.0  Inbox Business Technologies
# 87668     Pakistan        year         109500.0  Inbox Business Technologies
# 784584    Pakistan        year         157500.0  Inbox Business Technologies
# 694061    Pakistan        year          79200.0           NorthBay Solutions
# 742964    Pakistan        year         185500.0           NorthBay Solutions
# 365714    Pakistan        year          45000.0           NorthBay Solutions
# 212617    Pakistan        year          79200.0           NorthBay Solutions
# 669770    Pakistan        year          96773.0                      AlGooru
# 546486    Pakistan        year          90940.0                    PMCL-JAZZ
# 208197    Pakistan        year          79200.0                        Reorg
# 213687    Pakistan        year          24000.0                     Flipdish
# 323311    Pakistan        year         146000.0                 Avanceon MEA
# 771324    Pakistan        year         224500.0                     PackageX
#
#                                                job_skills  \
# 725905  ['python', 'java', 'scala', 'aws', 'redshift',...
# 319286  ['sql', 'go', 'sql server', 'oracle', 'power b...
# 202409                  ['java', 'sql', 'go', 'redshift']
# 176946       ['python', 'keras', 'pytorch', 'tensorflow']
# 652867          ['scala', 'postgresql', 'mysql', 'spark']
# 716278                 ['sql', 'python', 'go', 'tableau']
# 75724                   ['python', 'sql', 'r', 'tableau']
# 725631  ['sql', 'python', 'go', 'databricks', 'snowfla...
# 754068  ['python', 'aws', 'jupyter', 'numpy', 'pandas'...
# 647099              ['sql', 'excel', 'tableau', 'looker']
# 35758                                   ['sql', 'python']
# 87668   ['r', 'python', 'sql', 'nosql', 'hadoop', 'spa...
# 784584                   ['sql', 'python', 'r', 'hadoop']
# 694061  ['python', 'java', 'sql', 'scala', 'aws', 'red...
# 742964  ['python', 'aws', 'jupyter', 'numpy', 'pandas'...
# 365714  ['python', 'java', 'scala', 'aws', 'redshift',...
# 212617  ['python', 'aws', 'gcp', 'tensorflow', 'pytorc...
# 669770                    ['sas', 'sas', 'excel', 'spss']
# 546486                                         ['oracle']
# 208197                                          ['excel']
# 213687  ['python', 'java', 'scala', 'sql', 'nosql', 'h...
# 323311  ['scala', 'azure', 'hadoop', 'spark', 'pandas'...
# 771324  ['python', 'javascript', 'sql', 'aws', 'gcp', ...
#
#                                           job_type_skills  job_posted_month
# 725905  {'async': ['jira'], 'cloud': ['aws', 'redshift...                 1
# 319286  {'analyst_tools': ['power bi', 'dax', 'tableau...                 1
# 202409  {'cloud': ['redshift'], 'programming': ['java'...                 1
# 176946  {'libraries': ['keras', 'pytorch', 'tensorflow...                 2
# 652867  {'databases': ['postgresql', 'mysql'], 'librar...                 3
# 716278  {'analyst_tools': ['tableau'], 'programming': ...                 3
# 75724   {'analyst_tools': ['tableau'], 'programming': ...                 4
# 725631  {'analyst_tools': ['power bi', 'tableau'], 'cl...                 5
# 754068  {'cloud': ['aws'], 'libraries': ['jupyter', 'n...                 5
# 647099  {'analyst_tools': ['excel', 'tableau', 'looker...                 6
# 35758                  {'programming': ['sql', 'python']}                 6
# 87668   {'analyst_tools': ['tableau', 'power bi'], 'li...                 6
# 784584  {'libraries': ['hadoop'], 'programming': ['sql...                 6
# 694061  {'cloud': ['aws', 'redshift', 'databricks', 's...                 7
# 742964  {'cloud': ['aws'], 'libraries': ['jupyter', 'n...                 7
# 365714  {'async': ['jira'], 'cloud': ['aws', 'redshift...                 7
# 212617  {'cloud': ['aws', 'gcp'], 'libraries': ['tenso...                 7
# 669770  {'analyst_tools': ['sas', 'excel', 'spss'], 'p...                 8
# 546486                              {'cloud': ['oracle']}                 8
# 208197                       {'analyst_tools': ['excel']}                 9
# 213687  {'analyst_tools': ['excel'], 'libraries': ['ha...                 9
# 323311  {'cloud': ['azure'], 'libraries': ['hadoop', '...                11
# 771324  {'cloud': ['aws', 'gcp'], 'libraries': ['nltk'...                12

# %%
us_jobs = df[df["job_country"]== "United States"]

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# 679       Tech Lead Software Engineer, TikTok Data Access      San Jose, CA
# 3448         Senior Python Developer for Data Engineering      New York, NY
# 186163  Tech Lead / Sr Data Scientist, Product Analyti...   Los Angeles, CA
# 421728                          Data Analyst - Operations   Los Angeles, CA
# 313161       Data Scientist - Security Clearance Required  Newport News, VA
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
# 108099                     via Recruit.net         Full-time
# 78139                      via Recruit.net         Full-time
# ...                                    ...               ...
# 679                           via LinkedIn         Full-time
# 3448                          via LinkedIn         Full-time
# 186163                        via LinkedIn         Full-time
# 421728                          via Indeed         Full-time
# 313161                     via IT JobServe         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# 365786                True                    Georgia 2023-01-01 00:17:55
# 366073               False                    Georgia 2023-01-01 00:17:58
# 108099               False    Illinois, United States 2023-01-01 00:21:09
# 78139                False     Florida, United States 2023-01-01 00:27:40
# ...                    ...                        ...                 ...
# 679                  False    Illinois, United States 2023-12-31 13:03:14
# 3448                 False                    Georgia 2023-12-31 13:32:38
# 186163               False  California, United States 2023-12-31 15:00:46
# 421728               False  California, United States 2023-12-31 16:00:07
# 313161               False                    Georgia 2023-12-31 17:31:57
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 108883                  False                  True  United States
# 365786                  False                  True  United States
# 366073                  False                 False  United States
# 108099                  False                 False  United States
# 78139                   False                  True  United States
# ...                       ...                   ...            ...
# 679                     False                  True  United States
# 3448                     True                 False  United States
# 186163                  False                  True  United States
# 421728                  False                  True  United States
# 313161                  False                 False  United States
#
#        salary_rate  salary_year_avg           company_name  \
# 108883        year         110000.0              PlanetArt
# 365786        year          90000.0     Goodwin Recruiting
# 366073        year          55000.0       Cogent Infotech.
# 108099        year         120531.0           Apple Valley
# 78139         year         300000.0                Datadog
# ...            ...              ...                    ...
# 679           year         317000.0                 TikTok
# 3448          year         140000.0                 Luxoft
# 186163        year         271526.5                 TikTok
# 421728        year          72750.0  Wilshire Law Firm Plc
# 313161        year         114062.5                 Leidos
#
#                                                job_skills  \
# 108883              ['python', 'sql', 'tableau', 'excel']
# 365786          ['sql', 'excel', 'powerpoint', 'outlook']
# 366073  ['sql', 'python', 'numpy', 'pandas', 'seaborn'...
# 108099            ['java', 'sql', 'sql server', 'spring']
# 78139                        ['scala', 'python', 'spark']
# ...                                                   ...
# 679     ['java', 'go', 'c++', 'python', 'mongodb', 'mo...
# 3448                                    ['python', 'sql']
# 186163                  ['sql', 'python', 'r', 'express']
# 421728                       ['sql', 'power bi', 'unity']
# 313161          ['python', 'r', 'sql', 'pandas', 'numpy']
#
#                                           job_type_skills  job_posted_month
# 108883  {'analyst_tools': ['tableau', 'excel'], 'progr...                 1
# 365786  {'analyst_tools': ['excel', 'powerpoint', 'out...                 1
# 366073  {'analyst_tools': ['excel', 'alteryx', 'tablea...                 1
# 108099  {'databases': ['sql server'], 'libraries': ['s...                 1
# 78139   {'libraries': ['spark'], 'programming': ['scal...                 1
# ...                                                   ...               ...
# 679     {'databases': ['mongodb', 'mysql', 'redis'], '...                12
# 3448                   {'programming': ['python', 'sql']}                12
# 186163  {'programming': ['sql', 'python', 'r'], 'webfr...                12
# 421728  {'analyst_tools': ['power bi'], 'other': ['uni...                12
# 313161  {'libraries': ['pandas', 'numpy'], 'programmin...                12
#
# [15766 rows x 17 columns]

# %%
pak_jobs.groupby("job_title_short")["salary_year_avg"].agg(["median", 'min','max','count',"mean"  ]).sort_values(by='median', ascending=False)
# Out:
#                              median       min       max  count           mean
# job_title_short
# Data Scientist             157500.0  109500.0  157500.0      3  141500.000000
# Data Engineer               96773.0   24000.0  147500.0      7   95924.714286
# Data Analyst                95187.5   79200.0  111175.0      2   95187.500000
# Senior Data Scientist       90940.0   90940.0   90940.0      1   90940.000000
# Machine Learning Engineer   79200.0   50400.0  224500.0      5  123760.000000
# Software Engineer           79200.0   79200.0   79200.0      2   79200.000000
# Business Analyst            57600.0   50400.0   64800.0      2   57600.000000
# Senior Data Engineer        45000.0   45000.0   45000.0      1   45000.000000

# %%
us_jobs.groupby("job_title_short")["salary_year_avg"].agg(["median", 'min','max','count',"mean"  ]).sort_values(by='median', ascending=False)
# Out:
#                              median      min       max  count           mean
# job_title_short
# Senior Data Scientist      155000.0  55000.0  475000.0   1241  159330.432029
# Machine Learning Engineer  150000.0  44408.5  315000.0    128  154240.382812
# Senior Data Engineer       150000.0  45000.0  375000.0   1058  151448.023186
# Data Scientist             130000.0  30000.0  960000.0   4553  139946.707204
# Software Engineer          130000.0  48982.0  375000.0    157  137964.929588
# Data Engineer              125000.0  23496.0  525000.0   2915  134226.676753
# Cloud Engineer             116100.0  42000.0  221844.0     20  120090.900000
# Senior Data Analyst        110000.0  35360.0  425000.0    913  115729.129954
# Business Analyst            90000.0  35000.0  387460.0    431   96175.447397
# Data Analyst                90000.0  25000.0  375000.0   4350   94553.964924

# %% [markdown]
# # Matplotlib

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------------
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-client                   1.12.3
# anaconda-navigator                2.3.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# async-lru                         2.0.4
# async-timeout                     4.0.3
# atomicwrites                      1.4.0
# attrs                             23.1.0
# Automat                           20.2.0
# autopep8                          2.0.4
# Babel                             2.11.0
# backcall                          0.2.0
# backports.functools-lru-cache     1.6.4
# backports.tempfile                1.0
# backports.weakref                 1.0.post1
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# bitarray                          2.5.1
# bkcharts                          0.2
# black                             24.4.2
# bleach                            4.1.0
# blinker                           1.6.2
# bokeh                             3.4.1
# boltons                           23.0.0
# boto3                             1.24.28
# botocore                          1.34.69
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# brotlipy                          0.7.0
# cachetools                        5.3.3
# certifi                           2024.7.4
# cffi                              1.16.0
# chardet                           4.0.0
# charset-normalizer                2.0.4
# click                             8.1.7
# cloudpickle                       2.2.1
# clyent                            1.2.2
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# comtypes                          1.1.10
# conda                             24.7.1
# conda-build                       24.5.1
# conda-content-trust               0.2.0
# conda_index                       0.5.0
# conda-libmamba-solver             24.1.0
# conda-pack                        0.6.0
# conda-package-handling            2.3.0
# conda_package_streaming           0.10.0
# conda-repo-cli                    1.0.88
# conda-token                       0.5.0+1.g2209e04
# conda-verify                      3.4.2
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.6.0
# cryptography                      42.0.5
# cssselect                         1.2.0
# cycler                            0.11.0
# Cython                            0.29.32
# cytoolz                           0.12.2
# daal4py                           2021.6.0
# dask                              2024.5.0
# dask-expr                         1.1.0
# datasets                          2.20.0
# datashader                        0.16.3
# datashape                         0.5.4
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2024.5.0
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# exceptiongroup                    1.2.0
# executing                         0.8.3
# fastjsonschema                    2.16.2
# filelock                          3.13.1
# flake8                            7.0.0
# Flask                             3.0.3
# fonttools                         4.51.0
# frozendict                        2.4.2
# frozenlist                        1.4.0
# fsspec                            2024.3.1
# future                            0.18.3
# gensim                            4.3.2
# gitdb                             4.0.7
# GitPython                         3.1.43
# glob2                             0.7
# gmpy2                             2.1.2
# greenlet                          3.0.1
# h5py                              3.11.0
# HeapDict                          1.0.1
# holoviews                         1.19.1
# huggingface_hub                   0.23.1
# hvplot                            0.10.0
# hyperlink                         21.0.0
# idna                              3.7
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.10.1
# imblearn                          0.0
# importlib-metadata                7.0.1
# importlib_resources               6.4.0
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            0.7.0
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.15.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.8.1
# isort                             5.13.2
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jdcal                             1.4.1
# jedi                              0.18.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jinja2-time                       0.2.0
# jmespath                          1.0.1
# joblib                            1.2.0
# json5                             0.9.6
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.19.2
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.0.11
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.25.1
# jupyterlab-widgets                1.0.0
# keyring                           24.3.1
# kiwisolver                        1.4.4
# lazy-object-proxy                 1.10.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      2.9
# libmambapy                        1.5.8
# linkify-it-py                     2.0.0
# llvmlite                          0.43.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              5.2.1
# lz4                               4.3.2
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.8.4
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.1.1
# mistune                           2.0.4
# mkl-fft                           1.3.8
# mkl-random                        1.2.4
# mkl-service                       2.4.0
# mock                              4.0.3
# more-itertools                    10.1.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# multiprocess                      0.70.15
# munkres                           1.1.4
# mypy                              1.10.0
# mypy-extensions                   1.0.0
# navigator-updater                 0.3.0
# nbclassic                         0.3.5
# nbclient                          0.8.0
# nbconvert                         7.10.0
# nbformat                          5.9.2
# nest-asyncio                      1.6.0
# networkx                          3.2.1
# nltk                              3.7
# nose                              1.3.7
# notebook                          7.0.8
# notebook_shim                     0.2.3
# numba                             0.60.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.7.0
# olefile                           0.46
# openpyxl                          3.1.2
# overrides                         7.4.0
# packaging                         23.2
# pandas                            2.2.2
# pandocfilters                     1.5.0
# panel                             1.4.4
# param                             2.1.1
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathlib                           1.0.1
# pathspec                          0.10.3
# patsy                             0.5.6
# pep8                              1.7.1
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.3.0
# pip                               24.0
# pkginfo                           1.10.0
# platformdirs                      3.10.0
# plotly                            5.22.0
# pluggy                            1.0.0
# ply                               3.11
# poyo                              0.5.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          3.20.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py                                1.11.0
# py-cpuinfo                        9.0.0
# pyarrow                           17.0.0
# pyarrow-hotfix                    0.6
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.11.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.2
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.4
# pyflakes                          3.2.0
# Pygments                          2.15.1
# PyHamcrest                        2.0.2
# PyJWT                             2.8.0
# pylint                            2.16.2
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.0.1
# pyOpenSSL                         24.0.0
# pyparsing                         3.0.9
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# pyrsistent                        0.18.0
# PySocks                           1.7.1
# pytest                            7.4.4
# python-dateutil                   2.9.0.post0
# python-json-logger                2.0.7
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.10.0
# python-slugify                    5.0.2
# python-snappy                     0.6.1
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyviz_comms                       3.0.2
# pywavelets                        1.5.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.2.2
# qtconsole                         5.5.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# referencing                       0.30.2
# regex                             2023.10.3
# requests                          2.32.2
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.3.5
# rope                              1.12.0
# rpds-py                           0.10.6
# Rtree                             1.0.1
# ruamel.yaml                       0.17.21
# ruamel.yaml.clib                  0.2.6
# ruamel-yaml-conda                 0.15.100
# s3fs                              2024.3.1
# s3transfer                        0.6.0
# scikit-image                      0.19.2
# scikit-learn                      1.0.2
# scikit-learn-intelex              2021.20221004.171935
# scipy                             1.13.1
# Scrapy                            2.11.1
# seaborn                           0.13.2
# Send2Trash                        1.8.2
# service-identity                  18.1.0
# setuptools                        69.5.1
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcollections                 2.1.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            7.3.7
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.10
# spyder                            5.5.1
# spyder-kernels                    2.5.0
# SQLAlchemy                        2.0.30
# stack-data                        0.2.0
# statsmodels                       0.14.2
# streamlit                         1.32.0
# sympy                             1.12
# tables                            3.9.2
# tabulate                          0.9.0
# TBB                               0.2
# tblib                             1.7.0
# tenacity                          8.2.2
# terminado                         0.17.1
# testpath                          0.6.0
# text-unidecode                    1.3
# textdistance                      4.2.1
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tinycss                           0.4
# tinycss2                          1.2.1
# tldextract                        3.2.0
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# tornado                           6.4.1
# tqdm                              4.66.4
# traitlets                         5.14.3
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typing_extensions                 4.11.0
# tzdata                            2023.3
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# unicodedata2                      15.1.0
# Unidecode                         1.2.0
# urllib3                           1.26.19
# w3lib                             2.1.2
# watchdog                          4.0.1
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# whatthepatch                      1.0.2
# wheel                             0.43.0
# widgetsnbextension                3.6.6
# win-inet-pton                     1.1.0
# win-unicode-console               0.5
# wincertstore                      0.2
# wrapt                             1.14.1
# xarray                            2023.6.0
# xlrd                              2.0.1
# XlsxWriter                        3.0.3
# xlwings                           0.31.4
# xxhash                            2.0.2
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.9.3
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.22.0

# %%
df.job_posted_date.head()
# Out:
# 108883   2023-01-01 00:02:56
# 334082   2023-01-01 00:06:13
# 365786   2023-01-01 00:17:55
# 366073   2023-01-01 00:17:58
# 108099   2023-01-01 00:21:09
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %%
date_counts= df.job_posted_date.value_counts()
date_counts= date_counts.sort_index()

# %%
type(date_counts)
# Out:
# pandas.core.series.Series

# %%
plt.plot(date_counts.index, date_counts)

# %%
df["job_posted_month"]=df["job_posted_date"].dt.month

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# 186163  Tech Lead / Sr Data Scientist, Product Analyti...   Los Angeles, CA
# 421728                          Data Analyst - Operations   Los Angeles, CA
# 313161       Data Scientist - Security Clearance Required  Newport News, VA
# 336301                                     Data scientist        Dallas, TX
# 327439                                Staff engineer data    Southfield, MI
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
# 108099                     via Recruit.net         Full-time
# ...                                    ...               ...
# 186163                        via LinkedIn         Full-time
# 421728                          via Indeed         Full-time
# 313161                     via IT JobServe         Full-time
# 336301                      via Talent.com         Full-time
# 327439                      via Talent.com         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# 334082               False                  Argentina 2023-01-01 00:06:13
# 365786                True                    Georgia 2023-01-01 00:17:55
# 366073               False                    Georgia 2023-01-01 00:17:58
# 108099               False    Illinois, United States 2023-01-01 00:21:09
# ...                    ...                        ...                 ...
# 186163               False  California, United States 2023-12-31 15:00:46
# 421728               False  California, United States 2023-12-31 16:00:07
# 313161               False                    Georgia 2023-12-31 17:31:57
# 336301               False                      Sudan 2023-12-31 23:40:22
# 327439               False                      Sudan 2023-12-31 23:40:32
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 108883                  False                  True  United States
# 334082                   True                 False      Argentina
# 365786                  False                  True  United States
# 366073                  False                 False  United States
# 108099                  False                 False  United States
# ...                       ...                   ...            ...
# 186163                  False                  True  United States
# 421728                  False                  True  United States
# 313161                  False                 False  United States
# 336301                  False                  True          Sudan
# 327439                  False                 False          Sudan
#
#        salary_rate  salary_year_avg                    company_name  \
# 108883        year         110000.0                       PlanetArt
# 334082        year          65000.0                           Spiff
# 365786        year          90000.0              Goodwin Recruiting
# 366073        year          55000.0                Cogent Infotech.
# 108099        year         120531.0                    Apple Valley
# ...            ...              ...                             ...
# 186163        year         271526.5                          TikTok
# 421728        year          72750.0           Wilshire Law Firm Plc
# 313161        year         114062.5                          Leidos
# 336301        year         162500.0  Cognizant Technology Solutions
# 327439        year         140000.0               Credit Acceptance
#
#                                                job_skills  \
# 108883              ['python', 'sql', 'tableau', 'excel']
# 334082                ['python', 'mysql', 'aws', 'azure']
# 365786          ['sql', 'excel', 'powerpoint', 'outlook']
# 366073  ['sql', 'python', 'numpy', 'pandas', 'seaborn'...
# 108099            ['java', 'sql', 'sql server', 'spring']
# ...                                                   ...
# 186163                  ['sql', 'python', 'r', 'express']
# 421728                       ['sql', 'power bi', 'unity']
# 313161          ['python', 'r', 'sql', 'pandas', 'numpy']
# 336301                                ['python', 'nosql']
# 327439                          ['express', 'kubernetes']
#
#                                           job_type_skills  job_posted_month
# 108883  {'analyst_tools': ['tableau', 'excel'], 'progr...                 1
# 334082  {'cloud': ['aws', 'azure'], 'databases': ['mys...                 1
# 365786  {'analyst_tools': ['excel', 'powerpoint', 'out...                 1
# 366073  {'analyst_tools': ['excel', 'alteryx', 'tablea...                 1
# 108099  {'databases': ['sql server'], 'libraries': ['s...                 1
# ...                                                   ...               ...
# 186163  {'programming': ['sql', 'python', 'r'], 'webfr...                12
# 421728  {'analyst_tools': ['power bi'], 'other': ['uni...                12
# 313161  {'libraries': ['pandas', 'numpy'], 'programmin...                12
# 336301               {'programming': ['python', 'nosql']}                12
# 327439  {'other': ['kubernetes'], 'webframeworks': ['e...                12
#
# [22003 rows x 17 columns]

# %%
monthly_counts=df.job_posted_month.value_counts()

monthly_counts=monthly_counts.sort_index()

monthly_counts
# Out:
# job_posted_month
# 1     2296
# 2     2010
# 3     2204
# 4     1876
# 5     1911
# 6     2331
# 7     2219
# 8     2095
# 9     1246
# 10    1310
# 11    1124
# 12    1381
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts.values)

# %% [markdown]
# # Bar Chart , Count of Job Posting

# %%
job_counts= df.job_title_short.value_counts()

# %%
plt.bar(job_counts.index ,job_counts)
plt.title("Posting by Job Tite")
plt.ylabel("Count of job posting ")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
job_counts= job_counts.sort_values(ascending= True)
plt.barh(job_counts.index, job_counts)
plt.show()

# %%
job_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='job_title_short'>

# %%
df.plot(x='job_posted_date', y='salary_year_avg', kind='line')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# # Matplotlib Exercise Basics

# %%
job_salary= df.groupby("job_title_short")["salary_year_avg"].median().sort_values()

# %%
job_salary.plot(kind='barh')
plt.xlabel('salary($USD)')
plt.ylabel('')
plt.title("Median Salary by Job Title")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 job_salary.plot(kind='barh')
#       2 plt.xlabel('salary($USD)')
#       3 plt.ylabel('')
#
# NameError: name 'job_salary' is not defined
