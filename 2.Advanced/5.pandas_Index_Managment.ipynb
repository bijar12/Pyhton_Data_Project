# %% [markdown]
# # Index Management

# %%
#importing libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# loading Data
dataset= load_dataset("lukebarousse/data_jobs")
df=dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ### Reset Index

# %%
df_pakistan
# Out:
#        index            job_title_short  \
# 0        308              Data Engineer
# 1        943              Data Engineer
# 2       1636  Machine Learning Engineer
# 3       2895  Machine Learning Engineer
# 4       4006             Data Scientist
# ...      ...                        ...
# 2143  784584             Data Scientist
# 2144  784773  Machine Learning Engineer
# 2145  784981              Data Engineer
# 2146  785175             Data Scientist
# 2147  785575      Senior Data Scientist
#
#                                               job_title         job_location  \
# 0     Data Science Engineer (Remote Job for Japan Co...    Karachi, Pakistan
# 1                     Senior Consultant - Data Engineer             Pakistan
# 2                             Machine Learning Engineer  Islamabad, Pakistan
# 3                                           ML Engineer     Lahore, Pakistan
# 4                            Senior Data Scientist Jobs    Karachi, Pakistan
# ...                                                 ...                  ...
# 2143                                     Data Scientist  Islamabad, Pakistan
# 2144                          Machine Learning Engineer     Lahore, Pakistan
# 2145               Data Engineer - Datastage Consultant  Islamabad, Pakistan
# 2146                                     Data Scientist     Lahore, Pakistan
# 2147                        Senior Analytics Engineer I  Islamabad, Pakistan
#
#                     job_via job_schedule_type  job_work_from_home  \
# 0                via Indeed         Full-time               False
# 1                via Jooble         Full-time               False
# 2                via Indeed         Full-time               False
# 3                via Indeed         Full-time               False
# 4       via Jobiflix.online         Full-time               False
# ...                     ...               ...                 ...
# 2143        via Ai-Jobs.net        Contractor               False
# 2144           via LinkedIn         Full-time               False
# 2145  via LinkedIn Pakistan         Full-time               False
# 2146  via LinkedIn Pakistan         Full-time               False
# 2147       via Startup Jobs         Full-time               False
#
#      search_location     job_posted_date  job_no_degree_mention  \
# 0           Pakistan 2023-03-01 13:19:38                  False
# 1           Pakistan 2023-09-13 13:14:17                   True
# 2           Pakistan 2023-05-25 13:30:41                  False
# 3           Pakistan 2023-06-22 13:19:25                  False
# 4           Pakistan 2023-01-01 13:40:38                  False
# ...              ...                 ...                    ...
# 2143        Pakistan 2023-06-07 06:17:01                  False
# 2144        Pakistan 2023-10-06 06:16:08                  False
# 2145        Pakistan 2023-01-18 06:18:01                  False
# 2146        Pakistan 2023-01-19 06:19:23                  False
# 2147        Pakistan 2023-01-05 06:46:05                   True
#
#       job_health_insurance job_country salary_rate  salary_year_avg  \
# 0                    False    Pakistan        None              NaN
# 1                    False    Pakistan        None              NaN
# 2                    False    Pakistan        None              NaN
# 3                    False    Pakistan        None              NaN
# 4                    False    Pakistan        None              NaN
# ...                    ...         ...         ...              ...
# 2143                 False    Pakistan        year         157500.0
# 2144                 False    Pakistan        None              NaN
# 2145                 False    Pakistan        None              NaN
# 2146                 False    Pakistan        None              NaN
# 2147                 False    Pakistan        None              NaN
#
#       salary_hour_avg                 company_name  \
# 0                 NaN                   TouchPoint
# 1                 NaN           ThoughtWorks, Inc.
# 2                 NaN                       eMumba
# 3                 NaN    NKU Technologies Pvt.Ltd.
# 4                 NaN                      Afiniti
# ...               ...                          ...
# 2143              NaN  Inbox Business Technologies
# 2144              NaN           Khazana Enterprise
# 2145              NaN                     Teradata
# 2146              NaN                         TenX
# 2147              NaN                    PMCL-JAZZ
#
#                                              job_skills  \
# 0                    ['java', 'scala', 'python', 'sql']
# 1     ['nosql', 'cassandra', 'aws', 'azure', 'kafka'...
# 2            ['python', 'go', 'pandas', 'scikit-learn']
# 3     ['python', 'r', 'java', 'tensorflow', 'pytorch...
# 4         ['python', 'r', 'sql', 'scikit-learn', 'mlr']
# ...                                                 ...
# 2143                   ['sql', 'python', 'r', 'hadoop']
# 2144  ['python', 'java', 'r', 'keras', 'pytorch', 's...
# 2145  ['sql', 'shell', 'python', 'nosql', 'mongodb',...
# 2146                             ['python', 'r', 'sql']
# 2147                                         ['oracle']
#
#                                         job_type_skills
# 0     {'programming': ['java', 'scala', 'python', 's...
# 1     {'cloud': ['aws', 'azure'], 'databases': ['cas...
# 2     {'libraries': ['pandas', 'scikit-learn'], 'pro...
# 3     {'libraries': ['tensorflow', 'pytorch', 'sciki...
# 4     {'libraries': ['scikit-learn', 'mlr'], 'progra...
# ...                                                 ...
# 2143  {'libraries': ['hadoop'], 'programming': ['sql...
# 2144  {'libraries': ['keras', 'pytorch', 'scikit-lea...
# 2145  {'cloud': ['azure', 'aws'], 'databases': ['mon...
# 2146            {'programming': ['python', 'r', 'sql']}
# 2147                              {'cloud': ['oracle']}
#
# [2148 rows x 18 columns]

# %%
df_pakistan.set_index('index', inplace=True)

# %%
df_pakistan
# Out:
#                   job_title_short  \
# index
# 308                 Data Engineer
# 943                 Data Engineer
# 1636    Machine Learning Engineer
# 2895    Machine Learning Engineer
# 4006               Data Scientist
# ...                           ...
# 784584             Data Scientist
# 784773  Machine Learning Engineer
# 784981              Data Engineer
# 785175             Data Scientist
# 785575      Senior Data Scientist
#
#                                                 job_title  \
# index
# 308     Data Science Engineer (Remote Job for Japan Co...
# 943                     Senior Consultant - Data Engineer
# 1636                            Machine Learning Engineer
# 2895                                          ML Engineer
# 4006                           Senior Data Scientist Jobs
# ...                                                   ...
# 784584                                     Data Scientist
# 784773                          Machine Learning Engineer
# 784981               Data Engineer - Datastage Consultant
# 785175                                     Data Scientist
# 785575                        Senior Analytics Engineer I
#
#                job_location                job_via job_schedule_type  \
# index
# 308       Karachi, Pakistan             via Indeed         Full-time
# 943                Pakistan             via Jooble         Full-time
# 1636    Islamabad, Pakistan             via Indeed         Full-time
# 2895       Lahore, Pakistan             via Indeed         Full-time
# 4006      Karachi, Pakistan    via Jobiflix.online         Full-time
# ...                     ...                    ...               ...
# 784584  Islamabad, Pakistan        via Ai-Jobs.net        Contractor
# 784773     Lahore, Pakistan           via LinkedIn         Full-time
# 784981  Islamabad, Pakistan  via LinkedIn Pakistan         Full-time
# 785175     Lahore, Pakistan  via LinkedIn Pakistan         Full-time
# 785575  Islamabad, Pakistan       via Startup Jobs         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# index
# 308                  False        Pakistan 2023-03-01 13:19:38
# 943                  False        Pakistan 2023-09-13 13:14:17
# 1636                 False        Pakistan 2023-05-25 13:30:41
# 2895                 False        Pakistan 2023-06-22 13:19:25
# 4006                 False        Pakistan 2023-01-01 13:40:38
# ...                    ...             ...                 ...
# 784584               False        Pakistan 2023-06-07 06:17:01
# 784773               False        Pakistan 2023-10-06 06:16:08
# 784981               False        Pakistan 2023-01-18 06:18:01
# 785175               False        Pakistan 2023-01-19 06:19:23
# 785575               False        Pakistan 2023-01-05 06:46:05
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# index
# 308                     False                 False    Pakistan        None
# 943                      True                 False    Pakistan        None
# 1636                    False                 False    Pakistan        None
# 2895                    False                 False    Pakistan        None
# 4006                    False                 False    Pakistan        None
# ...                       ...                   ...         ...         ...
# 784584                  False                 False    Pakistan        year
# 784773                  False                 False    Pakistan        None
# 784981                  False                 False    Pakistan        None
# 785175                  False                 False    Pakistan        None
# 785575                   True                 False    Pakistan        None
#
#         salary_year_avg  salary_hour_avg                 company_name  \
# index
# 308                 NaN              NaN                   TouchPoint
# 943                 NaN              NaN           ThoughtWorks, Inc.
# 1636                NaN              NaN                       eMumba
# 2895                NaN              NaN    NKU Technologies Pvt.Ltd.
# 4006                NaN              NaN                      Afiniti
# ...                 ...              ...                          ...
# 784584         157500.0              NaN  Inbox Business Technologies
# 784773              NaN              NaN           Khazana Enterprise
# 784981              NaN              NaN                     Teradata
# 785175              NaN              NaN                         TenX
# 785575              NaN              NaN                    PMCL-JAZZ
#
#                                                job_skills  \
# index
# 308                    ['java', 'scala', 'python', 'sql']
# 943     ['nosql', 'cassandra', 'aws', 'azure', 'kafka'...
# 1636           ['python', 'go', 'pandas', 'scikit-learn']
# 2895    ['python', 'r', 'java', 'tensorflow', 'pytorch...
# 4006        ['python', 'r', 'sql', 'scikit-learn', 'mlr']
# ...                                                   ...
# 784584                   ['sql', 'python', 'r', 'hadoop']
# 784773  ['python', 'java', 'r', 'keras', 'pytorch', 's...
# 784981  ['sql', 'shell', 'python', 'nosql', 'mongodb',...
# 785175                             ['python', 'r', 'sql']
# 785575                                         ['oracle']
#
#                                           job_type_skills
# index
# 308     {'programming': ['java', 'scala', 'python', 's...
# 943     {'cloud': ['aws', 'azure'], 'databases': ['cas...
# 1636    {'libraries': ['pandas', 'scikit-learn'], 'pro...
# 2895    {'libraries': ['tensorflow', 'pytorch', 'sciki...
# 4006    {'libraries': ['scikit-learn', 'mlr'], 'progra...
# ...                                                   ...
# 784584  {'libraries': ['hadoop'], 'programming': ['sql...
# 784773  {'libraries': ['keras', 'pytorch', 'scikit-lea...
# 784981  {'cloud': ['azure', 'aws'], 'databases': ['mon...
# 785175            {'programming': ['python', 'r', 'sql']}
# 785575                              {'cloud': ['oracle']}
#
# [2148 rows x 17 columns]

# %%
median_pivot=df_pakistan.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=["median","min",'max'])

median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  57600.0         50400.0         64800.0
# Data Analyst                      95187.5         79200.0        111175.0
# Data Engineer                     96773.0         24000.0        147500.0
# Data Scientist                   157500.0        109500.0        157500.0
# Machine Learning Engineer         79200.0         50400.0        224500.0
# Senior Data Engineer              45000.0         45000.0         45000.0
# Senior Data Scientist             90940.0         90940.0         90940.0
# Software Engineer                 79200.0         79200.0         79200.0

# %%
median_pivot.sort_values(by=('median',"salary_year_avg"), ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Data Scientist                   157500.0        109500.0        157500.0
# Data Engineer                     96773.0         24000.0        147500.0
# Data Analyst                      95187.5         79200.0        111175.0
# Senior Data Scientist             90940.0         90940.0         90940.0
# Machine Learning Engineer         79200.0         50400.0        224500.0
# Software Engineer                 79200.0         79200.0         79200.0
# Business Analyst                  57600.0         50400.0         64800.0
# Senior Data Engineer              45000.0         45000.0         45000.0

# %%
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  57600.0         50400.0         64800.0
# Data Analyst                      95187.5         79200.0        111175.0
# Data Engineer                     96773.0         24000.0        147500.0
# Data Scientist                   157500.0        109500.0        157500.0
# Machine Learning Engineer         79200.0         50400.0        224500.0
# Senior Data Engineer              45000.0         45000.0         45000.0
# Senior Data Scientist             90940.0         90940.0         90940.0
# Software Engineer                 79200.0         79200.0         79200.0
